# %% [markdown]
# <a href="https://colab.research.google.com/github/jeetshah5/ML-2-Prac/blob/main/CNN_MNIST(FASHION)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CNN (MNIST DIGIT DATASET)**

# %% [markdown]
# Insert Code wherever represented with "#***************#"

# %% [markdown]
# # Importing Libraries

# %%
import keras
import cv2
import numpy as np
from keras.datasets import fashion_mnist
from keras.models import Sequential , load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
import matplotlib.pyplot as plt
from keras.utils import plot_model

# %% [markdown]
# # Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train= x_train.reshape(60000,28,28)

x_test= x_test.reshape(x_test.shape[0],28,28)

input_shape=(28,28,1)

y_train=keras.utils.to_categorical(y_train,10)

y_test=keras.utils.to_categorical(y_test,10)

x_train= x_train.astype('float32')
x_test= x_test.astype('float32')

for i in range(10):
  plt.imshow(x_train[i])
  plt.subplot(5,2,i+1)
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# <ipython-input-10-c540e36ae3c4>:18: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(5,2,i+1)

# %% [markdown]
# # Build CNN Model

# %%
x_train /= 255
x_test /=255
model = None  #Initialize model here

'''
Define batch size of 64 ,
No of classes (interpret from data)
Train for 5 epochs

'''

def build_model(optimizer):

  '''
  Define a sequential model with categorical cross entropy as loss function consisting
  2 convolution and 2 pooling layers with relu as activation function followed by
  droput -> flatten -> dense -> dropout -> dense

  Convolution layer - (kernel size = (3*3))
  Pooling layer - (pool size = (2*2))

  '''

  #****** INSERT MODEL CODE HERE ******

  return model

#**** call build model with RMSprop and SGDOptimizer Optimizer ****


plot_model(model, to_file="mnist model"+ '.jpg', show_shapes=True)
hist=model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test,y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  dropout (Dropout)           (None, 5, 5, 32)          0
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 256)               205056
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# ...
# Total params: 217,194
# Trainable params: 217,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# ...

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.optimizers import RMSprop, SGD
from keras.utils import plot_model

# Load Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Reshape and normalize the data
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32') / 255
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32') / 255

y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Parameters
batch_size = 64
epochs = 5

# Build model function
def build_model(optimizer):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# Build models with different optimizers
model_rmsprop = build_model(RMSprop())
model_sgd = build_model(SGD())

# Plot model architecture
plot_model(model_rmsprop, to_file="mnist_model_rmsprop.jpg", show_shapes=True)
plot_model(model_sgd, to_file="mnist_model_sgd.jpg", show_shapes=True)

# Train the models
hist_rmsprop = model_rmsprop.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                                 verbose=1, validation_data=(x_test, y_test))

hist_sgd = model_sgd.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                         verbose=1, validation_data=(x_test, y_test))
# Out:
# ...
# 4422102/4422102 [==============================] - 1s 0us/step
# Epoch 1/5
# 938/938 [==============================] - 80s 84ms/step - loss: 0.6039 - accuracy: 0.7810 - val_loss: 0.3992 - val_accuracy: 0.8544
# Epoch 2/5
# 938/938 [==============================] - 60s 64ms/step - loss: 0.3941 - accuracy: 0.8597 - val_loss: 0.3266 - val_accuracy: 0.8827
# Epoch 3/5
# 938/938 [==============================] - 61s 65ms/step - loss: 0.3450 - accuracy: 0.8777 - val_loss: 0.3306 - val_accuracy: 0.8814
# Epoch 4/5
# 938/938 [==============================] - 65s 69ms/step - loss: 0.3222 - accuracy: 0.8865 - val_loss: 0.2952 - val_accuracy: 0.8958
# Epoch 5/5
# 938/938 [==============================] - 60s 64ms/step - loss: 0.3047 - accuracy: 0.8929 - val_loss: 0.3361 - val_accuracy: 0.8873
# Epoch 1/5
# 938/938 [==============================] - 58s 61ms/step - loss: 1.3896 - accuracy: 0.4895 - val_loss: 0.7855 - val_accuracy: 0.7229
# Epoch 2/5
# ...

# %%
y1=hist.history['accuracy']
y2=hist.history['val_accuracy']
plt.plot(y1)
plt.plot(y2)

# %%
import matplotlib.pyplot as plt

# Extract training history for RMSprop optimizer
y1_rmsprop = hist_rmsprop.history['accuracy']
y2_rmsprop = hist_rmsprop.history['val_accuracy']

# Extract training history for SGD optimizer
y1_sgd = hist_sgd.history['accuracy']
y2_sgd = hist_sgd.history['val_accuracy']

# Plot training and validation accuracy for RMSprop
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(y1_rmsprop, label='Training Accuracy (RMSprop)')
plt.plot(y2_rmsprop, label='Validation Accuracy (RMSprop)')
plt.title('Training and Validation Accuracy (RMSprop)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation accuracy for SGD
plt.subplot(1, 2, 2)
plt.plot(y1_sgd, label='Training Accuracy (SGD)')
plt.plot(y2_sgd, label='Validation Accuracy (SGD)')
plt.title('Training and Validation Accuracy (SGD)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Predict Image

# %%
keras.models.save_model(model, "mnist.h5", save_format="h5")

labels = {0 : "T-shirt/top", 1: "Trouser", 2: "Pullover", 3: "Dress", 4: "Coat",
          5: "Sandal", 6: "Shirt", 7: "Sneaker", 8: "Bag", 9: "Ankle Boot"}

def predict_image(model, img):

  '''
  Reshape the image into (1,28,28)
  predict the answer and print it

  '''
  #**** Insert code here ****


m = load_model('/content/mnist.h5')
predict_image(m, x_test[7])
plt.imshow(x_test[7],cmap='gray')
# Out:
# 1/1 [==============================] - 0s 71ms/step
# [[2.3701428e-03 6.1609288e-05 1.2226738e-02 7.2117883e-04 1.2293209e-01
#   2.2050817e-05 8.5784298e-01 3.4762900e-07 3.8184042e-03 4.3993005e-06]]
# Shirt

# %%
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# Load the saved model
model = load_model('/content/mnist.h5')

# Define the labels dictionary
labels = {0: "T-shirt/top", 1: "Trouser", 2: "Pullover", 3: "Dress", 4: "Coat",
          5: "Sandal", 6: "Shirt", 7: "Sneaker", 8: "Bag", 9: "Ankle Boot"}

def predict_image(model, img):
    # Reshape the image into (1, 28, 28, 1) as the model expects batches
    img = img.reshape((1, 28, 28, 1))

    # Make prediction
    predictions = model.predict(img)

    # Get the predicted class index
    predicted_class = np.argmax(predictions)

    # Print the predicted label
    print("Predicted label:", labels[predicted_class])

# Plot the test image
plt.imshow(x_test[7].reshape(28, 28), cmap='gray')
plt.show()

# Make a prediction on the test image
predict_image(model, x_test[7])
# Out:
# 1/1 [==============================] - 0s 120ms/step
# Predicted label: Bag
